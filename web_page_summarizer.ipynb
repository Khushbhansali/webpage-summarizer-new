# %%
# !pip install sumy requests beautifulsoup4
# Out:
# Requirement already satisfied: sumy in c:\users\mahij\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: requests in c:\users\mahij\anaconda3\lib\site-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\mahij\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: pycountry>=18.2.23 in c:\users\mahij\anaconda3\lib\site-packages (from sumy) (24.6.1)
# Requirement already satisfied: nltk>=3.0.2 in c:\users\mahij\anaconda3\lib\site-packages (from sumy) (3.7)
# Requirement already satisfied: breadability>=0.1.20 in c:\users\mahij\anaconda3\lib\site-packages (from sumy) (0.1.20)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in c:\users\mahij\anaconda3\lib\site-packages (from sumy) (0.6.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mahij\anaconda3\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mahij\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahij\anaconda3\lib\site-packages (from requests) (2025.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahij\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mahij\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: chardet in c:\users\mahij\anaconda3\lib\site-packages (from breadability>=0.1.20->sumy) (4.0.0)
# Requirement already satisfied: lxml>=2.0 in c:\users\mahij\anaconda3\lib\site-packages (from breadability>=0.1.20->sumy) (4.9.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mahij\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (2022.7.9)
# Requirement already satisfied: click in c:\users\mahij\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\mahij\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (4.64.1)
# Requirement already satisfied: joblib in c:\users\mahij\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (1.1.1)
# Requirement already satisfied: colorama in c:\users\mahij\anaconda3\lib\site-packages (from click->nltk>=3.0.2->sumy) (0.4.6)

# %%
from sumy.parsers.html import HtmlParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words

def summarize_url(url, sentences_count=5):
    LANGUAGE = "english"
    parser = HtmlParser.from_url(url, Tokenizer(LANGUAGE))
    stemmer = Stemmer(LANGUAGE)

    summarizer = LsaSummarizer(stemmer)
    summarizer.stop_words = get_stop_words(LANGUAGE)

    summary = ""
    for sentence in summarizer(parser.document, sentences_count):
        summary += str(sentence) + " "
    return summary.strip()

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mahij\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
url = "https://www.pinterest.com/pin/5136987063089161/"
summary = summarize_url(url, sentences_count=5)
print("✅ Summary:\n")
print(summary)
# Out:
# ✅ Summary:
#
# Short Story | English stories for kids, English moral stories, English short storiesteacherfunfiles.blogspot.com Do you love reading? Here are some short stories written in English that kids can use to practice reading and their comprehension.
